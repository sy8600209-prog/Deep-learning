# %%
import sys
print(sys.executable)
# Out:
# C:\Users\sagar\anaconda3\envs\deep\python.exe

# %%
import torch 
import torch.nn as nn

# %%
imput =torch.tensor([1.0,2.0,3.0])
neuron=nn.Linear(in_features=3,out_features=1)

# %%
output=neuron(imput)

# %%
output
# Out:
# tensor([-0.0700], grad_fn=<ViewBackward0>)

# %%
neuron.weight @ imput + neuron.bias
# Out:
# tensor([-0.0700], grad_fn=<AddBackward0>)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[-0.4146,  0.3353, -0.1948]], requires_grad=True)
